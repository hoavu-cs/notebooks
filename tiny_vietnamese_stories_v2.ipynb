# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import random
import pickle
import math
from tqdm import tqdm
from tokenizers import ByteLevelBPETokenizer
from tokenizers.processors import BertProcessing
from transformers import AutoTokenizer, BertTokenizer
from sklearn.model_selection import train_test_split
import gc
from tokenizers import ByteLevelBPETokenizer, processors

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)


if not torch.cuda.is_available():
    print("CUDA is not available on your system.")
else:
    # Print the number of CUDA devices
    print(f"Number of CUDA Devices: {torch.cuda.device_count()}\n")

    for i in range(torch.cuda.device_count()):
        print(f"Device {i}:")
        print(f"    Name: {torch.cuda.get_device_name(i)}")
        print(f"    Computational Capability: {torch.cuda.get_device_capability(i)}")
        print(f"    Total Memory: {torch.cuda.get_device_properties(i).total_memory / (1024**2):.2f} MB\n")
# Out:
# cuda
# Number of CUDA Devices: 1
#
# Device 0:
#     Name: NVIDIA GeForce RTX 3090
#     Computational Capability: (8, 6)
#     Total Memory: 24575.50 MB

# %%
data_path = 'datasets/tiny_stories/'

# %%
filename = 'tiny_stories.csv'
filepath = os.path.join(data_path, filename)

data = pd.read_csv(filepath)
data = data.dropna()

print(data.head())
# Out:
#    Unnamed: 0                                                 en  \
# 0           0  Once upon a time, there was a little boy named...
# 1           1  Once upon a time, there was a normal boy named...
# 2           2  Once upon a time, there was a fast car named S...
# 3           3  Once there was a family with a very playful go...
# 4           4  Once upon a time, there was a dog named Max. M...
#
#                                                   vi
# 0  Ngày xửa ngày xưa, có một cậu bé tên Tim. Tim ...
# 1  Ngày xửa ngày xưa, có một cậu bé bình thường t...
# 2  Ngày xửa ngày xưa, có một chiếc xe tốc độ tên ...
# 3  Có một gia đình có một con dê rất hay vui đùa....
# 4  Ngày xửa ngày xưa, có một con chó tên là Max. ...

# %%
N = len(data)
train_size = int(0.9 * N)
train_data = data[:train_size]
val_data = data[train_size:]

print(train_data.shape, val_data.shape)
# Out:
# (2339822, 3) (259981, 3)

# %%
from transformers import BertTokenizer, AutoModel, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base-v2")

# Get the IDs
cls_id = tokenizer.cls_token_id
sep_id = tokenizer.sep_token_id
unk_id = tokenizer.unk_token_id
pad_id = tokenizer.pad_token_id

print("PAD Token ID:", pad_id)
print("UNK Token ID:", unk_id)
print("CLS Token ID:", cls_id)
print("SEP Token ID:", sep_id)
# Out:
# PAD Token ID: 1
# UNK Token ID: 3
# CLS Token ID: 0
# SEP Token ID: 2

# %%
BLOCK_SIZE = 256
VOCAB_SIZE = tokenizer.vocab_size
print('Vocab size is ', VOCAB_SIZE)
# Out:
# Vocab size is  64000

# %%
def get_batch(data, block_size, batch_size):
    x = torch.zeros((batch_size, block_size), dtype=torch.long)
    y = torch.zeros((batch_size, block_size), dtype=torch.long)
    samples = data['vi'].sample(n=batch_size)

    for i, sample in enumerate(samples):
        summary_ids = tokenizer.encode(sample)
        summary_ids = [id for id in summary_ids if id != unk_id]
        if len(summary_ids) < block_size + 2:
            summary_ids = summary_ids + [pad_id] * (block_size + 2 - len(summary_ids))
        random_start = random.randint(0, len(summary_ids) - block_size - 2)
        x[i, :len(summary_ids)] = torch.tensor(summary_ids[random_start:random_start + block_size], dtype=torch.long)
        y[i, :len(summary_ids)] = torch.tensor(summary_ids[random_start + 1:random_start + block_size + 1], dtype=torch.long)

    return x, y

a, b = get_batch(train_data, block_size=BLOCK_SIZE, batch_size=1)
print(a.shape, b.shape)
print(tokenizer.decode(a[0].tolist(), skip_special_tokens=False))
print(tokenizer.decode(b[0].tolist(), skip_special_tokens=False))
# Out:
# torch.Size([1, 256]) torch.Size([1, 256])
# <s> Một ngày nọ, một cậu bé tên Tim tìm thấy một chiếc mai trong sân nhà mình. Cậu rất vui mừng. Tim muốn chơi với chiếc mai và nghĩ rằng "Mình có thể sáng tạo với cái mai này"Tim đến chỗ Sally, bạn của anh. Anh chỉ cho cô ấy thấy chiếc mai và Sally nói: "Wow! Chúng ta có thể làm gì với chiếc mai?" Tim nghĩ một lúc rồi nảy ra ý tưởng. Anh nói: 'Hãy đào một cái hố và làm một hồ bơi nhỏ để làm đồ chơi'Sally thích ý tưởng này. Họ bắt đầu đào bằng thuổng. Họ đào và đào. Chẳng mấy chốc, họ đã có một cái hố nhỏ. Tim đề nghị, "Hãy đặt nước vào trong lỗ" Họ đổ đầy nước vào hố. Bây giờ, họ có một bể bơi nhỏ để làm đồ chơi cho mình.Tim và Sally chơi với đồ chơi của họ trong hồ bơi. Họ đã rất vui vẻ. Họ hạnh phúc vì tìm thấy chiếc thuổng và có thể sáng tạo với nó. </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Một ngày nọ, một cậu bé tên Tim tìm thấy một chiếc mai trong sân nhà mình. Cậu rất vui mừng. Tim muốn chơi với chiếc mai và nghĩ rằng "Mình có thể sáng tạo với cái mai này"Tim đến chỗ Sally, bạn của anh. Anh chỉ cho cô ấy thấy chiếc mai và Sally nói: "Wow! Chúng ta có thể làm gì với chiếc mai?" Tim nghĩ một lúc rồi nảy ra ý tưởng. Anh nói: 'Hãy đào một cái hố và làm một hồ bơi nhỏ để làm đồ chơi'Sally thích ý tưởng này. Họ bắt đầu đào bằng thuổng. Họ đào và đào. Chẳng mấy chốc, họ đã có một cái hố nhỏ. Tim đề nghị, "Hãy đặt nước vào trong lỗ" Họ đổ đầy nước vào hố. Bây giờ, họ có một bể bơi nhỏ để làm đồ chơi cho mình.Tim và Sally chơi với đồ chơi của họ trong hồ bơi. Họ đã rất vui vẻ. Họ hạnh phúc vì tìm thấy chiếc thuổng và có thể sáng tạo với nó. </s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>

# %%
del model, xb, yb  # delete the tensor variable
torch.cuda.empty_cache()  # clear unused memory in PyTorch
gc.collect()  # call Python garbage collector

# %%
N_EMB = 800
N_LAYERS = 4
N_HEADS = 4
DROPOUT = 0.2


def estimate_loss(model, val_data, block_size, batch_size):
    model.eval()
    with torch.no_grad():
        x, y = get_batch(val_data, block_size, batch_size)
        x, y = x.to(device), y.to(device)
        _, loss = model(x, y)
    model.train()
    return loss.item()

def generate_square_subsequent_mask(sz):
    mask = (torch.tril(torch.ones(sz, sz)) == 1).float()
    mask = mask.masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def get_sine_position_encodings(length, dim):
    pos = torch.arange(length, dtype=torch.float32).reshape(-1, 1)
    div_term = torch.exp(torch.arange(0, dim, 2).float() * -(math.log(10000.0) / dim))
    pos_encodings = torch.zeros(length, dim)
    pos_encodings[:, 0::2] = torch.sin(pos * div_term)
    pos_encodings[:, 1::2] = torch.cos(pos * div_term)
    return pos_encodings

class LanguageModel(nn.Module):

    def __init__(self, vocab_size, n_emb, block_size, n_layers, n_heads, dropout=0.2):
        super(LanguageModel, self).__init__()

        self.token_embedding_table = nn.Embedding(vocab_size, n_emb)
        self.position_embedding_table = nn.Embedding(block_size, n_emb)
        self.block_size = block_size

        encoder_layer = nn.TransformerEncoderLayer(d_model=n_emb, nhead=n_heads, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

        self.feed_forward = nn.Sequential(
            nn.Linear(n_emb, 4 * n_emb),
            nn.ReLU(),
            nn.Linear(4 * n_emb, n_emb)
        )

        self.lm_head = nn.Linear(n_emb, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        token_emb = self.token_embedding_table(idx)
        position_emb = self.position_embedding_table(torch.arange(T, device=device))

        x = token_emb + position_emb
        x_transform = x.clone()
        mask = generate_square_subsequent_mask(T).to(device)

        x_transform = self.transformer_encoder(x_transform.permute(1, 0, 2), mask=mask)
        x_transform = x_transform.permute(1, 0, 2)
        x = x + x_transform

        x = self.feed_forward(x)
        logits = self.lm_head(x)

        if targets is not None:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)
            return logits, loss
        else:
            return logits, None


    def generate(self, idx, max_new_tokens, temperature=1.0, stop_token=False):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -self.block_size:]
            logits, _ = self.forward(idx_cond)

            # Scale logits by the temperature
            logits = logits[:, -1, :] / temperature

            probs = F.softmax(logits, dim=-1)
            idx_new = torch.multinomial(probs, num_samples=1)
            idx = torch.cat([idx, idx_new], dim=-1)
            if stop_token and idx_new.item() == sep_id:
                break
        return idx

# Create model, optimizer
model = LanguageModel(vocab_size=VOCAB_SIZE, block_size=BLOCK_SIZE, n_emb=N_EMB, n_layers=N_LAYERS, \
    n_heads=N_HEADS, dropout=DROPOUT).to(device)

print(f'Number of parameters {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
# Out:
# Number of parameters 131176992

# %%
model_path = os.path.join(data_path, "vietnamese_tiny_stories_4layers.pth")
print(model_path)
model = torch.load(model_path)
# Out:
# datasets/tiny_stories/vietnamese_tiny_stories_4layers.pth

# %%
EARLY_STOP = 50
N_EPOCHS = 20000
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

last_val_loss = 1e9
early_stop = EARLY_STOP

for steps in range(N_EPOCHS):
    model.train()
    xb, yb = get_batch(train_data, block_size=BLOCK_SIZE, batch_size=BATCH_SIZE)
    xb = xb.to(device)
    yb = yb.to(device)
    logits, loss = model(xb, yb)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Delete xb, yb and free GPU memory
    del xb, yb
    torch.cuda.empty_cache()

    if steps % 100 == 0:
        print('Step:', steps, 'Training Loss:', loss.item())
        val_loss = estimate_loss(model, val_data, block_size=BLOCK_SIZE, batch_size=BATCH_SIZE)
        print('Validation loss:', val_loss)
        # if val_loss >= last_val_loss:
        #     early_stop -= 1
        #     if early_stop == 0:
        #         print('Early stop!')
        #         break
        # else:
        #     early_stop = EARLY_STOP
        #     last_val_loss = val_loss
# Out:
# Step: 0 Training Loss: 11.12340259552002
# Validation loss: 9.132868766784668
# Step: 100 Training Loss: 3.631944417953491
# Validation loss: 3.5089168548583984
# Step: 200 Training Loss: 2.831491470336914
# Validation loss: 3.315843105316162
# Step: 300 Training Loss: 2.9097506999969482
# Validation loss: 2.712236166000366
# Step: 400 Training Loss: 2.764423370361328
# Validation loss: 2.630145788192749
# Step: 500 Training Loss: 2.649531602859497
# Validation loss: 2.380825996398926
# Step: 600 Training Loss: 2.355130910873413
# Validation loss: 2.4677348136901855
# Step: 700 Training Loss: 2.51491641998291
# Validation loss: 2.37542462348938
# Step: 800 Training Loss: 2.2452855110168457
# Validation loss: 2.074643611907959
# Step: 900 Training Loss: 2.143148899078369
# Validation loss: 2.309785842895508
# Step: 1000 Training Loss: 2.4260692596435547
# Validation loss: 2.0690059661865234
# Step: 1100 Training Loss: 2.2619242668151855
# Validation loss: 2.1847000122070312
# Step: 1200 Training Loss: 2.1206932067871094
# Validation loss: 2.1367135047912598
# Step: 1300 Training Loss: 2.112578868865967
# Validation loss: 2.075577974319458
# Step: 1400 Training Loss: 2.135179042816162
# Validation loss: 2.1194040775299072
# Step: 1500 Training Loss: 2.1461470127105713
# Validation loss: 1.949804425239563
# Step: 1600 Training Loss: 2.2324843406677246
# Validation loss: 2.0764214992523193
# Step: 1700 Training Loss: 1.9303332567214966
# Validation loss: 1.7768783569335938
# Step: 1800 Training Loss: 2.100618839263916
# Validation loss: 1.923005223274231
# Step: 1900 Training Loss: 1.9869180917739868
# Validation loss: 1.892407774925232
# Step: 2000 Training Loss: 2.0955276489257812
# Validation loss: 1.9948346614837646
# Step: 2100 Training Loss: 1.8129630088806152
# Validation loss: 2.016232967376709
# Step: 2200 Training Loss: 1.9976407289505005
# Validation loss: 1.7857853174209595
# Step: 2300 Training Loss: 2.0904479026794434
# Validation loss: 1.8089114427566528
# Step: 2400 Training Loss: 2.141922950744629
# Validation loss: 1.714263677597046
# Step: 2500 Training Loss: 2.0469281673431396
# Validation loss: 1.8154146671295166
# Step: 2600 Training Loss: 1.9013986587524414
# Validation loss: 1.7503103017807007
# Step: 2700 Training Loss: 1.7187986373901367
# Validation loss: 1.996442198753357
# Step: 2800 Training Loss: 1.9665822982788086
# Validation loss: 1.7270468473434448
# Step: 2900 Training Loss: 1.7261006832122803
# Validation loss: 1.9065792560577393
# Step: 3000 Training Loss: 1.8421813249588013
# Validation loss: 1.644075870513916
# Step: 3100 Training Loss: 1.8194260597229004
# Validation loss: 1.6277357339859009
# Step: 3200 Training Loss: 1.8315194845199585
# Validation loss: 1.731553077697754
# Step: 3300 Training Loss: 1.9355437755584717
# Validation loss: 1.794661283493042
# Step: 3400 Training Loss: 1.9901179075241089
# Validation loss: 1.7510871887207031
# Step: 3500 Training Loss: 1.8074791431427002
# Validation loss: 1.8954342603683472
# Step: 3600 Training Loss: 1.8299214839935303
# Validation loss: 2.002345561981201
# Step: 3700 Training Loss: 1.867303729057312
# Validation loss: 1.7783465385437012
# Step: 3800 Training Loss: 1.622657060623169
# Validation loss: 1.5551199913024902
# Step: 3900 Training Loss: 1.7928732633590698
# Validation loss: 1.5794222354888916
# Step: 4000 Training Loss: 1.9477291107177734
# Validation loss: 1.6559805870056152
# Step: 4100 Training Loss: 1.8102617263793945
# Validation loss: 1.8304271697998047
# Step: 4200 Training Loss: 1.9370050430297852
# Validation loss: 1.7081124782562256
# Step: 4300 Training Loss: 1.74508535861969
# Validation loss: 1.8064510822296143
# Step: 4400 Training Loss: 1.7115355730056763
# Validation loss: 1.6137213706970215
# Step: 4500 Training Loss: 1.7990895509719849
# Validation loss: 1.6115909814834595
# Step: 4600 Training Loss: 1.66286301612854
# Validation loss: 1.6527681350708008
# Step: 4700 Training Loss: 1.7356643676757812
# Validation loss: 1.8171743154525757
# Step: 4800 Training Loss: 1.5710575580596924
# Validation loss: 1.6353305578231812
# Step: 4900 Training Loss: 1.8951411247253418
# Validation loss: 1.7120301723480225
# Step: 5000 Training Loss: 1.4991583824157715
# Validation loss: 1.5599485635757446
# Step: 5100 Training Loss: 1.7397853136062622
# Validation loss: 1.6538065671920776
# Step: 5200 Training Loss: 1.65300714969635
# Validation loss: 1.6979118585586548
# Step: 5300 Training Loss: 1.641223430633545
# Validation loss: 1.6853628158569336
# Step: 5400 Training Loss: 1.6636223793029785
# Validation loss: 1.7378058433532715
# Step: 5500 Training Loss: 1.6239705085754395
# Validation loss: 1.8056849241256714
# Step: 5600 Training Loss: 1.6356651782989502
# Validation loss: 1.5540180206298828
# Step: 5700 Training Loss: 1.7277016639709473
# Validation loss: 1.583733081817627
# Step: 5800 Training Loss: 1.7931880950927734
# Validation loss: 1.6143162250518799
# Step: 5900 Training Loss: 1.5794404745101929
# Validation loss: 1.5899291038513184
# Step: 6000 Training Loss: 1.7790496349334717
# Validation loss: 1.5784045457839966
# Step: 6100 Training Loss: 1.9195644855499268
# Validation loss: 1.6275193691253662
# Step: 6200 Training Loss: 1.694962501525879
# Validation loss: 1.5672056674957275
# Step: 6300 Training Loss: 1.6102429628372192
# Validation loss: 1.6263548135757446
# Step: 6400 Training Loss: 1.4428330659866333
# Validation loss: 1.6246349811553955
# Step: 6500 Training Loss: 1.6664899587631226
# Validation loss: 1.535538911819458
# Step: 6600 Training Loss: 1.7007384300231934
# Validation loss: 1.583370566368103
# Step: 6700 Training Loss: 1.6232808828353882
# Validation loss: 1.65101957321167
# Step: 6800 Training Loss: 1.5424168109893799
# Validation loss: 1.4547630548477173
# Step: 6900 Training Loss: 1.6091856956481934
# Validation loss: 1.5449057817459106
# Step: 7000 Training Loss: 1.5705559253692627
# Validation loss: 1.6099132299423218
# Step: 7100 Training Loss: 1.5315603017807007
# Validation loss: 1.6816790103912354
# Step: 7200 Training Loss: 1.510019063949585
# Validation loss: 1.4931042194366455
# Step: 7300 Training Loss: 1.6940807104110718
# Validation loss: 1.68097984790802
# Step: 7400 Training Loss: 1.5377856492996216
# Validation loss: 1.5279170274734497
# Step: 7500 Training Loss: 1.6360969543457031
# Validation loss: 1.5738978385925293
# Step: 7600 Training Loss: 1.4715338945388794
# Validation loss: 1.5331870317459106
# Step: 7700 Training Loss: 1.508298635482788
# Validation loss: 1.4424580335617065
# Step: 7800 Training Loss: 1.5278483629226685
# Validation loss: 1.5652879476547241
# Step: 7900 Training Loss: 1.6198283433914185
# Validation loss: 1.2750396728515625
# Step: 8000 Training Loss: 1.55783212184906
# Validation loss: 1.6376829147338867
# Step: 8100 Training Loss: 1.6609777212142944
# Validation loss: 1.4537642002105713
# Step: 8200 Training Loss: 1.6024202108383179
# Validation loss: 1.4855530261993408
# Step: 8300 Training Loss: 1.6694854497909546
# Validation loss: 1.7864643335342407
# Step: 8400 Training Loss: 1.4864590167999268
# Validation loss: 1.5095977783203125
# Step: 8500 Training Loss: 1.5137794017791748
# Validation loss: 1.5797755718231201
# Step: 8600 Training Loss: 1.6589709520339966
# Validation loss: 1.4556587934494019
# Step: 8700 Training Loss: 1.7241215705871582
# Validation loss: 1.6269404888153076
# Step: 8800 Training Loss: 1.606808066368103
# Validation loss: 1.4489250183105469
# Step: 8900 Training Loss: 1.6205493211746216
# Validation loss: 1.5895800590515137
# Step: 9000 Training Loss: 1.5676600933074951
# Validation loss: 1.6697161197662354
# Step: 9100 Training Loss: 1.509587049484253
# Validation loss: 1.4611364603042603
# Step: 9200 Training Loss: 1.7134978771209717
# Validation loss: 1.521060585975647
# Step: 9300 Training Loss: 1.3444676399230957
# Validation loss: 1.5574047565460205
# Step: 9400 Training Loss: 1.675541877746582
# Validation loss: 1.5286024808883667
# Step: 9500 Training Loss: 1.778241753578186
# Validation loss: 1.4754372835159302
# Step: 9600 Training Loss: 1.6157070398330688
# Validation loss: 1.5298372507095337
# Step: 9700 Training Loss: 1.4832227230072021
# Validation loss: 1.6423505544662476
# Step: 9800 Training Loss: 1.5481898784637451
# Validation loss: 1.4629642963409424
# Step: 9900 Training Loss: 1.5760701894760132
# Validation loss: 1.4500916004180908
# Step: 10000 Training Loss: 1.5877550840377808
# Validation loss: 1.327487587928772
# Step: 10100 Training Loss: 1.5514824390411377
# Validation loss: 1.613667368888855
# Step: 10200 Training Loss: 1.5455242395401
# Validation loss: 1.6165752410888672
# Step: 10300 Training Loss: 1.692720651626587
# Validation loss: 1.5115931034088135
# Step: 10400 Training Loss: 1.7389849424362183
# Validation loss: 1.5158004760742188
# Step: 10500 Training Loss: 1.5441601276397705
# Validation loss: 1.743111252784729
# Step: 10600 Training Loss: 1.5572962760925293
# Validation loss: 1.6398146152496338
# Step: 10700 Training Loss: 1.6217076778411865
# Validation loss: 1.537765622138977
# Step: 10800 Training Loss: 1.639737844467163
# Validation loss: 1.5276333093643188
# Step: 10900 Training Loss: 1.6485384702682495
# Validation loss: 1.5073424577713013
# Step: 11000 Training Loss: 1.5676270723342896
# Validation loss: 1.4216495752334595
# Step: 11100 Training Loss: 1.516034722328186
# Validation loss: 1.5698961019515991
# Step: 11200 Training Loss: 1.6794018745422363
# Validation loss: 1.3776565790176392
# Step: 11300 Training Loss: 1.3242452144622803
# Validation loss: 1.5282336473464966
# Step: 11400 Training Loss: 1.4669994115829468
# Validation loss: 1.617750883102417
# Step: 11500 Training Loss: 1.5819493532180786
# Validation loss: 1.593909502029419
# Step: 11600 Training Loss: 1.580993413925171
# Validation loss: 1.5917847156524658
# Step: 11700 Training Loss: 1.5913631916046143
# Validation loss: 1.5212047100067139
# Step: 11800 Training Loss: 1.7317432165145874
# Validation loss: 1.5219454765319824
# Step: 11900 Training Loss: 1.3897976875305176
# Validation loss: 1.550430178642273
# Step: 12000 Training Loss: 1.4764641523361206
# Validation loss: 1.4945765733718872
# Step: 12100 Training Loss: 1.4851677417755127
# Validation loss: 1.3225998878479004
# Step: 12200 Training Loss: 1.4609514474868774
# Validation loss: 1.5676454305648804
# Step: 12300 Training Loss: 1.4848335981369019
# Validation loss: 1.6028430461883545
# Step: 12400 Training Loss: 1.344153881072998
# Validation loss: 1.4733154773712158
# Step: 12500 Training Loss: 1.384255290031433
# Validation loss: 1.431993007659912
# Step: 12600 Training Loss: 1.4333887100219727
# Validation loss: 1.3535091876983643
# Step: 12700 Training Loss: 1.4981592893600464
# Validation loss: 1.6395281553268433
# Step: 12800 Training Loss: 1.4820070266723633
# Validation loss: 1.4244452714920044
# Step: 12900 Training Loss: 1.508141040802002
# Validation loss: 1.4334017038345337
# Step: 13000 Training Loss: 1.5659781694412231
# Validation loss: 1.654444694519043
# Step: 13100 Training Loss: 1.547201156616211
# Validation loss: 1.520511507987976
# Step: 13200 Training Loss: 1.5296735763549805
# Validation loss: 1.3782954216003418
# Step: 13300 Training Loss: 1.5086147785186768
# Validation loss: 1.4185363054275513
# Step: 13400 Training Loss: 1.6413787603378296
# Validation loss: 1.6708800792694092
# Step: 13500 Training Loss: 1.4872970581054688
# Validation loss: 1.5052320957183838
# Step: 13600 Training Loss: 1.6120789051055908
# Validation loss: 1.4313551187515259
# Step: 13700 Training Loss: 1.351906657218933
# Validation loss: 1.4778400659561157
# Step: 13800 Training Loss: 1.442660927772522
# Validation loss: 1.398491621017456
# Step: 13900 Training Loss: 1.670061707496643
# Validation loss: 1.5233410596847534
# Step: 14000 Training Loss: 1.5682917833328247
# Validation loss: 1.4071192741394043
# Step: 14100 Training Loss: 1.5919461250305176
# Validation loss: 1.325950264930725
# Step: 14200 Training Loss: 1.501894474029541
# Validation loss: 1.3931676149368286
# Step: 14300 Training Loss: 1.6270214319229126
# Validation loss: 1.390405297279358
# Step: 14400 Training Loss: 1.389443039894104
# Validation loss: 1.5169472694396973
# Step: 14500 Training Loss: 1.3969662189483643
# Validation loss: 1.45106840133667
# Step: 14600 Training Loss: 1.6413986682891846
# Validation loss: 1.349090576171875
# Step: 14700 Training Loss: 1.3772192001342773
# Validation loss: 1.5251997709274292
# Step: 14800 Training Loss: 1.522078037261963
# Validation loss: 1.490385890007019
# Step: 14900 Training Loss: 1.530134916305542
# Validation loss: 1.401814579963684
# Step: 15000 Training Loss: 1.4334015846252441
# Validation loss: 1.3992445468902588
# Step: 15100 Training Loss: 1.6038928031921387
# Validation loss: 1.2688831090927124
# Step: 15200 Training Loss: 1.4464250802993774
# Validation loss: 1.4526270627975464
# Step: 15300 Training Loss: 1.4760538339614868
# Validation loss: 1.4714452028274536
# Step: 15400 Training Loss: 1.4637025594711304
# Validation loss: 1.5329960584640503
# Step: 15500 Training Loss: 1.5718671083450317
# Validation loss: 1.6016907691955566
# Step: 15600 Training Loss: 1.5981909036636353
# Validation loss: 1.311913251876831
# Step: 15700 Training Loss: 1.5320076942443848
# Validation loss: 1.2911840677261353
# Step: 15800 Training Loss: 1.3406126499176025
# Validation loss: 1.4975130558013916
# Step: 15900 Training Loss: 1.5438556671142578
# Validation loss: 1.426532506942749
# Step: 16000 Training Loss: 1.420749545097351
# Validation loss: 1.4134501218795776
# Step: 16100 Training Loss: 1.4728721380233765
# Validation loss: 1.49788236618042
# Step: 16200 Training Loss: 1.506035566329956
# Validation loss: 1.37939453125
# Step: 16300 Training Loss: 1.4860248565673828
# Validation loss: 1.3515417575836182
# Step: 16400 Training Loss: 1.4920405149459839
# Validation loss: 1.4254170656204224
# Step: 16500 Training Loss: 1.2296723127365112
# Validation loss: 1.484341025352478
# Step: 16600 Training Loss: 1.4518074989318848
# Validation loss: 1.446153163909912
# Step: 16700 Training Loss: 1.5104455947875977
# Validation loss: 1.5089635848999023
# Step: 16800 Training Loss: 1.5205671787261963
# Validation loss: 1.4531484842300415
# Step: 16900 Training Loss: 1.5862796306610107
# Validation loss: 1.3427884578704834
# Step: 17000 Training Loss: 1.4706107378005981
# Validation loss: 1.4961411952972412
# Step: 17100 Training Loss: 1.5185879468917847
# Validation loss: 1.5053001642227173
# Step: 17200 Training Loss: 1.500145435333252
# Validation loss: 1.6026899814605713
# Step: 17300 Training Loss: 1.5799633264541626
# Validation loss: 1.3626774549484253
# Step: 17400 Training Loss: 1.6302787065505981
# Validation loss: 1.365360140800476
# Step: 17500 Training Loss: 1.4722572565078735
# Validation loss: 1.3969511985778809
# Step: 17600 Training Loss: 1.6863278150558472
# Validation loss: 1.4292911291122437
# Step: 17700 Training Loss: 1.6358742713928223
# Validation loss: 1.397547721862793
# Step: 17800 Training Loss: 1.506925344467163
# Validation loss: 1.415884256362915
# Step: 17900 Training Loss: 1.5331482887268066
# Validation loss: 1.564024806022644
# Step: 18000 Training Loss: 1.599230170249939
# Validation loss: 1.4144479036331177
# Step: 18100 Training Loss: 1.4413779973983765
# Validation loss: 1.5197948217391968
# Step: 18200 Training Loss: 1.3515607118606567
# Validation loss: 1.3880864381790161
# Step: 18300 Training Loss: 1.5921043157577515
# Validation loss: 1.38126540184021
# Step: 18400 Training Loss: 1.380542278289795
# Validation loss: 1.513632893562317
# Step: 18500 Training Loss: 1.3943110704421997
# Validation loss: 1.3897674083709717
# Step: 18600 Training Loss: 1.479305624961853
# Validation loss: 1.2542574405670166
# Step: 18700 Training Loss: 1.3755983114242554
# Validation loss: 1.318205714225769
# Step: 18800 Training Loss: 1.465348482131958
# Validation loss: 1.4188045263290405
# Step: 18900 Training Loss: 1.5153473615646362
# Validation loss: 1.438289999961853
# Step: 19000 Training Loss: 1.4377061128616333
# Validation loss: 1.3415724039077759
# Step: 19100 Training Loss: 1.4421192407608032
# Validation loss: 1.2993746995925903
# Step: 19200 Training Loss: 1.500459909439087
# Validation loss: 1.4475562572479248
# Step: 19300 Training Loss: 1.4521872997283936
# Validation loss: 1.2888418436050415
# Step: 19400 Training Loss: 1.5830543041229248
# Validation loss: 1.2739691734313965
# Step: 19500 Training Loss: 1.3950095176696777
# Validation loss: 1.4692820310592651
# Step: 19600 Training Loss: 1.3756710290908813
# Validation loss: 1.4722872972488403
# Step: 19700 Training Loss: 1.516876220703125
# Validation loss: 1.354476809501648
# Step: 19800 Training Loss: 1.5661662817001343
# Validation loss: 1.4603084325790405
# Step: 19900 Training Loss: 1.6055988073349
# Validation loss: 1.5053799152374268

# %%
model_path = os.path.join(data_path, "vietnamese_tiny_stories_4layers.pth")
torch.save(model, model_path)

# %%
starting_tokens = 'Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. '
encoded_start = tokenizer.encode(starting_tokens)
encoded_start.pop(-1)
len_starting_tokens = len(encoded_start)

idx = torch.tensor(encoded_start).reshape(1, len_starting_tokens).to(device)
model.eval()
N_SAMPLES = 10
for _ in range(N_SAMPLES):
    generation = model.generate(idx, max_new_tokens=2000, temperature=0.5, stop_token=True)[0].tolist()
    story = tokenizer.decode(generation, skip_special_tokens=True)

    print('Story ', _ + 1, ':')
    print(story)
    print('\n')
# Out:
# Story  1 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó nhìn thấy một cái cây to, một cái ao xinh xắn. Mèo con rất vui vẻ. Nó muốn chơi với cái ao đó.Mèo con chơi với cái ao cả ngày. Nó lăn nó quanh hồ, giả vờ là một hoàng tử. Con mèo con rất vui vẻ. Khi đến lúc về nhà, nó chào tạm biệt cái ao và đi ngủ. Nó biết mình sẽ sớm được chơi với cái ao xinh đẹp này thôi.
#
#
# Story  2 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó thấy một cái cây lớn với quả ngon lành trên đó. Mèo con rất vui sướng. Nó muốn ăn trái cây đó.Mèo con bắt đầu ăn trái cây. Nó không biết rằng trái cây này rất ngon. Nó cố gắng lấy trái cây nhưng nó quá cao nên không với tới được. Nó cảm thấy buồn bã.Rồi một cô gái tốt bụng nhìn thấy con mèo. Cô muốn giúp đỡ nó. Cô trèo lên cây và hái trái cây. Mèo con rất vui vẻ. Mèo con và cô gái chơi với nhau suốt ngày.
#
#
# Story  3 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó thấy bạn bè đang chơi trò chơi. Mèo con đang vui vẻ.Con mèo con hỏi bạn mình, con chó, "Cậu có thể cho tớ mượn đồ chơi được không?" Con chó nói, "Vâng, tôi có thể mượn đồ chơi của cậu." Vì vậy, mèo con đã cho mèo con mượn đồ chơi từ nhà của mình.Con mèo con rất vui vẻ. Nó chơi với món đồ chơi cả ngày. Con mèo con và con chó trở thành những người bạn tốt.
#
#
# Story  4 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó nhìn thấy một cái cây lớn với rất nhiều lá. Mèo con muốn có một cành cây để chơi với nó. Mèo con bắt đầu lắc cành cây.Mèo con rất vui vẻ. Nó cố gắng lấy cành cây, nhưng nó quá cao. Mèo con cố gắng hết lần này đến lần khác, nhưng không thể với tới cành cây. Mèo con bắt đầu khóc. Nó không biết phải làm gì.Sau đó, một con chim nhỏ đến và nhìn thấy mèo con đang khóc. Con chim nói, "Đừng khóc, mèo con. Chúng ta có thể chơi với cành cây cùng nhau." Mèo con vui mừng và nói, "Cảm ơn, chim" Con chim và mèo con chơi với cành cây và trở thành những người bạn tốt.
#
#
# Story  5 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó rất vui khi được chơi ngoài trời. Nó thấy nhiều đứa trẻ đang chơi đùa và cười đùa.Mèo con muốn tham gia cùng họ. Nó chạy đến chỗ bọn trẻ và nói, "Chào! Bạn có muốn chơi với tôi không?"Bọn trẻ nói, "Có, chúng ta có thể chơi cùng nhau. Hãy chơi với đồ chơi của bạn." Mèo con và bọn trẻ chơi suốt ngày. Chúng chạy nhảy và cười đùa. Mèo con không còn buồn nữaCuối ngày, mèo con về nhà. Mèo con vui vì nó đã có một ngày vui vẻ chơi đùa với bạn bè. Mèo con nói, "Tạm biệt các bạn, mèo con! Tôi hy vọng chúng ta có thể sớm được chơi lại." Mèo con vui vì có một người bạn mới để chơi cùng.
#
#
# Story  6 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó nhìn thấy một quả bóng đỏ to tướng trên cỏ. Mèo con muốn chơi với quả banh đó.Mèo con cố đá quả bóng nhưng nó quá nặng. Nó cố gắng và cố gắng, nhưng không thể làm được.Một con chó nhỏ nhìn thấy mèo con và nói, "Con có cần giúp đỡ không?" Mèo con nói, "Vâng, làm ơn" Con chó cố gắng đá quả bóng nhưng quả bóng quá nặng.Ngay sau đó, một con chim nhỏ bay xuống và nói, "Tôi có thể giúp bạn đá quả bóng" Con chim dùng đôi cánh khoẻ mạnh của mình để đẩy quả bóng. Quả bóng lăn ra và con chim rất vui mừng. Con chim nói, "Cảm ơn, chim" Chúng chơi với quả bóng cùng nhau và đã có một ngày tuyệt vời.
#
#
# Story  7 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó vui vẻ và thích chơi ngoài trời. Nó nhìn thấy một cái cây lớn với rất nhiều chim. Mèo con thích chim và muốn chơi đùa cùng chúng.Mèo con chạy đến cái cây và bắt đầu chơi với những con chim. Chúng đang rất vui vẻ. Mèo con nhìn thấy một cái cây lớn và cũng muốn trèo lên nó. Mèo con cố gắng trèo lên nhưng không thể leo lên được nữa. Mèo con cảm thấy buồn bã.Sau đó, một con chim nhỏ đến và nhìn thấy mèo con trên cây. Con chim nói, "Tôi có thể giúp bạn leo lên cây" Con mèo bé rất vui mừng và nói, "Cảm ơn, chim" Họ đã trèo lên cây và chơi cùng nhau cả ngày dài. Mèo con không còn buồn nữa.
#
#
# Story  8 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó thích chơi với bạn bè trong sân. Nó tìm thấy một cái cây lớn với rất nhiều lá. Mèo con thích chơi trốn tìm.Mèo con tìm thấy một chỗ ẩn nấp tuyệt vời và nấp sau nó. Nó tìm thấy một cái cây và nấp đằng sau nó. Nó tìm thấy một chỗ ẩn nấp hoàn hảo. Mèo con rất hạnh phúc và bắt đầu tìm kiếm một nơi ẩn náu tốt để ẩn nấp.Mèo con tìm thấy một chỗ ẩn nấp hoàn hảo. Nó tìm thấy một chỗ ẩn nấp hoàn hảo trong bụi cây và nấp dưới nó, con mèo con rất vui khi tìm được chỗ ẩn nấp hoàn hảo. Mèo con nhảy ra khỏi bụi cây và nấp vào một cái cây nơi ẩn nấp ẩn nấp hoàn hảo. Mèo con rất vui khi tìm được nơi ẩn nấp hoàn hảo.
#
#
# Story  9 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó nhảy nhót quanh quẩn trong khi nhìn thấy một cái cây lớn. Nó nghĩ trèo lên cây sẽ rất vui.Mèo con bắt đầu leo lên cây. Nó cảm thấy hạnh phúc và hạnh phúc. Nó cảm thấy như mình đang ở trên cao.Nhưng rồi, một con chim nhỏ bay xuống và nói, "Xin chào Mittens! Bạn đang làm gì vậy?" Mèo con nói, "Tôi đang cố gắng trèo lên cây nhưng tôi không thể leo lên cây được." Con chim nhỏ muốn giúp đỡ Mittens. Chim nhỏ nói, "Tôi có thể giúp bạn, mèo con."Chúng cứ thử và thử, nhưng không thành công. Chúng không thể leo lên cây. Mèo con buồn bã. Nhưng sau đó, một con chim tốt bụng đã nhìn thấy mèo con. Con chim nói, "Đừng buồn. Tôi có thể giúp bạn." Con mèo con rất vui vẻ và cảm ơn chú chim. Mèo con học được rằng giúp đỡ người khác có thể mang lại niềm vui cho bạn
#
#
# Story  10 :
# Hôm nay trời nắng. Mèo con đi học chẳng mang thứ gì. Nó thấy một cái cây to, một bông hoa xinh xắn và một bông hoa xinh xắn. Mèo con rất vui khi được chơi trong công viên.Khi Mittens đang chơi, cô nhìn thấy một con chim nhỏ. Con chim buồn bã. Mèo con muốn giúp con chim. Mèo con nói, "Đừng buồn, chú chim nhỏ. Tôi sẽ giúp bạn."Mèo con và mèo con cùng nhau chơi trong công viên. Chúng đã rất vui vẻ. Cuối cùng, mèo con không còn buồn nữa. Mèo con và con chim trở thành những người bạn tốt. Chúng chơi trong công viên mỗi ngày.
